# %%
## Why pandas?
## Why not excel always?


## Very limited functions
## Handle a lot of data; struggles, crashes, hangs

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
## Importing the pandas library
import pandas as pd

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !pwd
# Out:
# /content

# %%
df = pd.read_csv('/content/drive/MyDrive/Refactor_Notes/Module1_Python/Pandas/survey_results_public.csv')
df.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor  ...                            WelcomeChange  \
# ...

# %%
## Checking rows and columns
## shape is an attribute not a method so no need of brackets
df.shape
# Out:
# (88883, 85)

# %%
## Checking the data type of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
## Changing options for display to see every column at once
pd.set_option("display.max_columns",85)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
## Increasing rows??
## How??

# %%
schema_df=pd.read_csv("/content/drive/MyDrive/Practice_Xaviers/survey_results_schema.csv")
schema_df.shape
# Out:
# (85, 2)

# %%
## How to see all the rows now?
pd.set_option("display.max_rows",85)

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88873       88062        NaN       No
# 88874       88076        NaN       No
# 88875       88182        NaN      Yes
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88873                                              Never
# 88874                                              Never
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# ...

# %%
#### Series and dataframe

# %%
df["MainBranch"]
# Out:
# 0                   I am a student who is learning to code
# 1                   I am a student who is learning to code
# 2        I am not primarily a developer, but I write co...
# 3                           I am a developer by profession
# 4                           I am a developer by profession
#                                ...
# 88878                                                  NaN
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882                                                  NaN
# Name: MainBranch, Length: 88883, dtype: object

# %%
type(df["MainBranch"])
# Out:
# pandas.core.series.Series

# %%
df.MainBranch
# Out:
# 0                   I am a student who is learning to code
# 1                   I am a student who is learning to code
# 2        I am not primarily a developer, but I write co...
# 3                           I am a developer by profession
# 4                           I am a developer by profession
#                                ...
# 88878                                                  NaN
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882                                                  NaN
# Name: MainBranch, Length: 88883, dtype: object

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
type(df.MainBranch)
# Out:
# pandas.core.series.Series

# %%
## Accessing multiple columns

df[["Country","MainBranch"]].head(3)
# Out:
#                   Country                                         MainBranch
# 0          United Kingdom             I am a student who is learning to code
# 1  Bosnia and Herzegovina             I am a student who is learning to code
# 2                Thailand  I am not primarily a developer, but I write co...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
## Accessing rows
## iloc and loc

#iloc using indexes

# %%
df.iloc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
## Selecting only rows (first argument), columns = second argument
df.iloc[[0,1]]  ###df.iloc[["Supply thr row indexes"], ["Here you can supply the column indexes"]]
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
## Selecting columns
df.iloc[[0,1],2]
# Out:
# 0    Yes
# 1     No
# Name: Hobbyist, dtype: object

# %%
df.iloc[[78,80],3]
# Out:
# 78                                                Never
# 80    Less than once a month but more than once per ...
# Name: OpenSourcer, dtype: object

# %%
## accessing via labels/names of the columns
df.loc[[0,1]]
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
df.loc[[0,1],["Country"]]
# Out:
#                   Country
# 0          United Kingdom
# 1  Bosnia and Herzegovina

# %%
## Getting two columns from the selected rows
df.loc[[0,1],["Country","Student"]]
# Out:
#                   Country         Student
# 0          United Kingdom              No
# 1  Bosnia and Herzegovina  Yes, full-time

# %%
df.loc[:, ["Hobbyist"]]
# Out:
#       Hobbyist
# 0          Yes
# 1           No
# 2          Yes
# 3           No
# 4          Yes
# ...        ...
# 88878      Yes
# 88879       No
# 88880       No
# 88881       No
# 88882      Yes
#
# [88883 rows x 1 columns]

# %%
### How many were Yes or No from Hobbyist?
### Lets first check whats inside the column?

df["Hobbyist"].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df["Hobbyist"].value_counts().plot(kind="bar")

# %%
##Fetching only first row

df.iloc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
## Fetch specific column "Hobbyist" from this first row
df.loc[0,"Hobbyist"]
# Out:
# 'Yes'

# %%
## Fetch first three rows and the same column
df.loc[0:2,"Hobbyist"]
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
## Get some more columns from these rows
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.loc[0:2,"Hobbyist"]
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
## Getting all columns till Employment

# %%
df.loc[0:2,"Hobbyist":"Employment"]
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %%
## Default indexes: identifiers for rows(unique)

# %%
## You need better index?
df["Respondent"].duplicated().

#df.tail(2)
#df.shape
# Out:
#   File "<ipython-input-45-ac09a1411573>", line 2
#     df["Respondent"].duplicated().
#                                   ^
# SyntaxError: invalid syntax

# %%
df.set_index("Respondent")

# %%
df.head()

# %%
df.set_index("Respondent", inplace=True)

# %%
df.head(2)

# %%
## Now these indexes become the labels of the data
df.loc[2]

# %%
## Also, it can be done while reading the file itself.

df=pd.read_csv("/content/drive/MyDrive/Refactor_Notes/Module1_Python/Pandas/survey_results_public.csv", index_col="Respondent")

# %%
df.head(2)

# %%
df.loc[1]

# %%
schema_df.head(80)

# %%
### Finding the specific column meaning from this
### Lets set an identifier to this as well so as to fetch from that label from the survey file
schema_df=pd.read_csv("/content/drive/MyDrive/Refactor_Notes/Module1_Python/Pandas/survey_results_schema.csv", index_col="Column")
schema_df.head(2)

# %%
## Now we can use loc to find via labels
schema_df.loc["Hobbyist"]

# %%
## Check something else??
df.columns

# %%
schema_df.loc["MgrIdiot"]

# %%
df["MgrIdiot"].value_counts().plot(kind="bar")

# %%
df["MGRIDIOT"].value_counts().plot(kind="line")

# %%
schema_df.loc["WorkRemote"]

# %%
schema_df

# %%
schema_df.loc["MgrIdiot"]

# %%
## sorting alphabetically
schema_df.sort_index()

# %%
schema_df.sort_index(ascending = False)  ## Arranging in descending order
schema_df

# %%
## what if we want to permanently do it in the dataframe itself?
schema_df.sort_index(inplace=True)
schema_df.index

# %%
schema_df.loc["ConvertedComp"]

# %%
## Filtering the data based on some conditions
df["ConvertedComp"]

# %%
df.columns

# %%
schema_df

# %%
df.shape

# %%
df.shape

# %%
## Filter of high salaries (>70,000)
high_salary=df[df["ConvertedComp"] > 70000]

# %%
high_salary.shape

# %%
### Fetching only certain columns from this filter
df.loc[high_salary,["Country","ConvertedComp"]]

# %%
## Filter out from certain countries only US,India, UK, Germany, Canada

countries=["United States","India","United Kingdom","Germany","Canada"]

df_5countries=df[df["Country"].isin(countries)]

# %%
df["Country"].value_counts()

# %%
df_5countries["Country"].value_counts()

# %%
df.head(4)

# %%
df["Student"].value_counts()

# %%
## Filter only those rows in which language worked with is Python
## First lets check what languages we have in this column

df["LanguageWorkedWith"].value_counts()

# %%
have_python=df[df["LanguageWorkedWith"].str.contains("Python", na=False)]
have_python.shape

##df[df["LanguageWorkedWith"]=="Python"]
#df.shape

# %%
a=df[df["LanguageWorkedWith"].str.contains("HTML|CSS", na=False)]   ## | and & operator 
a["LanguageWorkedWith"]

# %%
have_python["LanguageWorkedWith"].head(2)

# %%
## Altering existing rows and columns in the dataframe

# %%
df.columns

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df.columns

# %%
## Changing it into upper case
## Go through loops/list comprehension

## Converting all the columns to a list

list_cols=df.columns.values.tolist()
list_cols

# %%
df.columns

# %%
df.head(2)

# %%
df.columns=[x.upper() for x in df.columns]

# %%
df.columns

# %%
## Quick revision
## Selcting columns BLOCKCHAINIS', 'BETTERLIFE from first two rows

df.loc[0:2,["BLOCKCHAINIS","BETTERLIFE"]]

# %%
## We previously filtered the df on the basis of the salary
## Lets rename the column name for better understanding
## Rename function

dict1={val1:key1, val2:key2}

df.rename(columns={"CONVERTEDCOMP" : "SalaryUSD"}, inplace=True)

# %%
df.columns

# %%
## now lets check put Hobbyist columm
## Lets check out its meaning first in case you have forgotten

schema_df.loc["Hobbyist"]

# %%
## Lets see again what it has?

df["HOBBYIST"].value_counts()

# %%
## Lets replace now Yes > True and No > False
## Maps a dictionary key to its values


## High : 3 Medium : 2 Low : 1


df["HOBBYIST"].map({"Yes":True,"No":False})

# %%
df["HOBBYIST"].value_counts()

# %%
df["HOBBYIST"]=df["HOBBYIST"].map({"Yes":True,"No":False})  ## There is no inplace for map so we need to reassign

# %%
df["HOBBYIST"].value_counts()

# %%
## What is there are other values than Yes or No, because map function will turn the other values as Nan
 ## Rather use replace method if the columns values have more than Yes or No


df['HOBBYIST'] = df['HOBBYIST'].replace([True,False],["Yes","No"])

# %%
df["HOBBYIST"].value_counts()

# %%
## Adding/Removing rows and columns
## Lets  create a new column first which is a combination of WORKLOC column and AGE column
## Lets see again what these column means actually?
df.columns
#df.head(2)

# %%
schema_df.loc["WorkLoc"]

# %%
df["WORKLOC"].value_counts()

# %%
df["AGE"].value_counts()

# %%
df[["WORKLOC","AGE"]].head(5)

#NEW_COLUMN
#Home 28

df.info()

# %%
df["WORKLOC"] = df["WORKLOC"].astype(str)
df["AGE"]=df["AGE"].astype(str)

# %%
df["workloc_age"]=df["WORKLOC"] + " " + df["AGE"]


df.head(2)

# %%
df.info()

# %%
df["workloc_age"]

# %%
df.columns

# %%
## Drop/Remove the columns

df.drop(columns=["EDLEVEL","EDUOTHER"]).head(2)

# %%
df[["EDLEVEL","EDUOTHER"]]

# %%
df.drop(columns=["EDLEVEL","EDUOTHER"], inplace=True)

# %%
df.columns

# %%
df[["EDLEVEL","EDUOTHER"]]

# %%
df["DEVENVIRON"].head(5)

# %%
## Lets split a column on the basis of a delimiter i.e. ; here
## Lets check out this column "DEVENVIRON"

df["DEVENVIRON"].head(2)

# %%
schema_df.set_index("Column", inplace=True)

# %%
#schema_df.loc["DevEnviron"]

df["DevEnviron"].str.split(";", expand=False) 

#df["DevEnviron"]
# Out:
# 0                           [IntelliJ, Notepad++, PyCharm]
# 1                                          [Atom, PyCharm]
# 2                                [Vim, Visual Studio Code]
# 3        [Eclipse, Vim, Visual Studio, Visual Studio Code]
# 4                               [IntelliJ, Notepad++, Vim]
#                                ...
# 88878            [Atom, Visual Studio, Visual Studio Code]
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882    [Android Studio, Atom, Eclipse, NetBeans, Note...
# Name: DevEnviron, Length: 88883, dtype: object

# %%
df["DevEnviron"].str.split(";", expand=True)  ## Assigning it into multiple columns with df[["col1_name","col2_name"....so on]]


#df[["col1","col2",....,"col21"]]=
# Out:
#                    0                   1                   2   \
# 0            IntelliJ           Notepad++             PyCharm
# 1                Atom             PyCharm                None
# 2                 Vim  Visual Studio Code                None
# 3             Eclipse                 Vim       Visual Studio
# 4            IntelliJ           Notepad++                 Vim
# ...               ...                 ...                 ...
# 88878            Atom       Visual Studio  Visual Studio Code
# 88879             NaN                 NaN                 NaN
# 88880             NaN                 NaN                 NaN
# 88881             NaN                 NaN                 NaN
# 88882  Android Studio                Atom             Eclipse
#
#                        3          4             5     6     7     8     9   \
# 0                    None       None          None  None  None  None  None
# ...

# %%
df["DEVENVIRON"].value_counts()
# Out:
# Visual Studio Code                                                             2141
# Visual Studio;Visual Studio Code                                               1675
# Notepad++;Visual Studio;Visual Studio Code                                     1362
# Vim                                                                             914
# Notepad++;Visual Studio                                                         817
#                                                                                ...
# NetBeans;PHPStorm;Zend                                                            1
# Atom;IntelliJ;IPython / Jupyter;NetBeans;Notepad++;PyCharm;Sublime Text;Vim       1
# Android Studio;Eclipse;Notepad++;Visual Studio Code;Xcode                         1
# Android Studio;Atom;Komodo;Visual Studio Code                                     1
# Android Studio;Eclipse;IntelliJ;Notepad++;PHPStorm;Vim;Visual Studio Code         1
# Name: DEVENVIRON, Length: 4714, dtype: int64

# %%
df.shape
# Out:
# (37307, 84)

# %%
### Sorting the dataframe on the basis of country

df.sort_values(by="COUNTRY", inplace =True)

df.head(3)
# Out:
#        RESPONDENT                      MAINBRANCH  HOBBYIST  \
# 39018       39258  I am a developer by profession      True
# 86551       87091  I am a developer by profession      True
# 58390       58760  I am a developer by profession      True
#
#                                              OPENSOURCER  \
# 39018                            Less than once per year
# 86551  Less than once a month but more than once per ...
# 58390                         Once a month or more often
#
#                                               OPENSOURCE          EMPLOYMENT  \
# 39018  OSS is, on average, of LOWER quality than prop...  Employed full-time
# 86551  The quality of OSS and closed source software ...  Employed full-time
# 58390  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#            COUNTRY STUDENT                                   EDLEVEL  \
# 39018  Afghanistan      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...

# %%
## Checking the convertedcomp i.e. salary for these countries

df[["COUNTRY","SalaryUSD"]].head(20)
# Out:
#                 COUNTRY  SalaryUSD
# Respondent
# 12310       Afghanistan        NaN
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0
# 10746       Afghanistan     3996.0
# 33178       Afghanistan        NaN
# 26340       Afghanistan        NaN
# 722         Afghanistan        0.0
# 29045       Afghanistan        NaN
# 7085        Afghanistan    14364.0
# 6417        Afghanistan        NaN
# 22450       Afghanistan     7980.0
# 28638       Afghanistan        0.0
# 7353        Afghanistan        NaN
# 36028           Albania     8832.0
# 18837           Albania        NaN
# 25109           Albania        NaN
# 33385           Albania        NaN
# 2332            Albania    22080.0
# 29164           Albania    13752.0
# 9441            Albania        NaN

# %%
## Sorting on both columns, lets say one ascending and one descending

df.sort_values(by=["COUNTRY","SalaryUSD"], ascending=[True,False], inplace=True)

# %%
df[["COUNTRY","SalaryUSD"]].head(50)
# Out:
#            COUNTRY  SalaryUSD
# 62723  Afghanistan  1000000.0
# 50172  Afghanistan   153216.0
# 39018  Afghanistan    19152.0
# 58082  Afghanistan    17556.0
# 7056   Afghanistan    14364.0
# 22327  Afghanistan     7980.0
# 48122  Afghanistan     4464.0
# 10697  Afghanistan     3996.0
# 8112   Afghanistan     1596.0
# 29560  Afghanistan     1116.0
# 28470  Afghanistan        0.0
# 719    Afghanistan        0.0
# 86551  Afghanistan        NaN
# 58390  Afghanistan        NaN
# 73920  Afghanistan        NaN
# 28877  Afghanistan        NaN
# 51525  Afghanistan        NaN
# 45562  Afghanistan        NaN
# 46807  Afghanistan        NaN
# 44123  Afghanistan        NaN
# 80423  Afghanistan        NaN
# 59184  Afghanistan        NaN
# 60185  Afghanistan        NaN
# 37571  Afghanistan        NaN
# 42832  Afghanistan        NaN
# 12253  Afghanistan        NaN
# 7323   Afghanistan        NaN
# 61770  Afghanistan        NaN
# 86394  Afghanistan        NaN
# 85293  Afghanistan        NaN
# ...

# %%
## Aggregation - mean,median,mode etc
## Lets look at the salary column


df["SalaryUSD"].head(50)
# Out:
# Respondent
# 7085      14364.0
# 22450      7980.0
# 10746      3996.0
# 8149       1596.0
# 29736      1116.0
# 722           0.0
# 28638         0.0
# 12310         NaN
# 33178         NaN
# 26340         NaN
# 29045         NaN
# 6417          NaN
# 7353          NaN
# 3787     114550.0
# 9270      74474.0
# 6716      60000.0
# 10303     57300.0
# 28873     34368.0
# 36574     23952.0
# 2332      22080.0
# 12265     18768.0
# 18295     13800.0
# 29164     13752.0
# 1954      11040.0
# 21700     11040.0
# 13385     10596.0
# 25100      9936.0
# 27637      9624.0
# 36028      8832.0
# 15993      8832.0
# 18869      7728.0
# 15374      7728.0
# 11549      6624.0
# 33593      5520.0
# 34211      5496.0
# 25589      4416.0
# 18837         NaN
# 25109         NaN
# 33385         NaN
# 9441          NaN
# 16157         NaN
# 20142         NaN
# 29415         NaN
# 6206          NaN
# 9229          NaN
# 18128         NaN
# 37363         NaN
# 26191         NaN
# 21754         NaN
# ...

# %%
## Lets find out the median of this series

df["SalaryUSD"].median()
# Out:
# 57287.0

# %%
## Lets check out the median salary countrywise

df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# COMPTOTAL      62000.0
# SalaryUSD      57287.0
# WORKWEEKHRS       40.0
# CODEREVHRS         4.0
# AGE               29.0
# Hobbyist           1.0
# dtype: float64

# %%
## Decribe method gives basic stats about the columns which are in float
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88883 entries, 62723 to 88881
# Data columns (total 86 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   RESPONDENT              88883 non-null  int64
#  1   MAINBRANCH              88331 non-null  object
#  2   HOBBYIST                88883 non-null  bool
#  3   OPENSOURCER             88883 non-null  object
#  4   OPENSOURCE              86842 non-null  object
#  5   EMPLOYMENT              87181 non-null  object
#  6   COUNTRY                 88751 non-null  object
#  7   STUDENT                 87014 non-null  object
#  8   EDLEVEL                 86390 non-null  object
#  9   UNDERGRADMAJOR          75614 non-null  object
#  10  EDUOTHER                84260 non-null  object
#  11  ORGSIZE                 71791 non-null  object
#  12  DEVTYPE                 81335 non-null  object
#  13  YEARSCODE               87938 non-null  object
# ...

# %%
df["COMPTOTAL"].count()
# Out:
# 23588

# %%
df["HOBBYIST"]
# Out:
# Respondent
# 7085     Yes
# 22450     No
# 10746    Yes
# 8149     Yes
# 29736    Yes
#         ...
# 26228    Yes
# 3991     Yes
# 6486     Yes
# 22975     No
# 251      Yes
# Name: HOBBYIST, Length: 37307, dtype: object

# %%
## Lets check how many people use different social media from the survey?
## Which column you will use?

df

# %%
df["SOCIALMEDIA"].value_counts()
# Out:
# Reddit                      6164
# YouTube                     5744
# WhatsApp                    5658
# Facebook                    5576
# Twitter                     4837
# Instagram                   2616
# I don't use social media    2346
# LinkedIn                    1816
# WeChat 微信                    277
# Snapchat                     268
# VK ВКонта́кте                238
# Weibo 新浪微博                    23
# Hello                         12
# Youku Tudou 优酷                10
# Name: SOCIALMEDIA, dtype: int64

# %%
## Based on the country lets get the same social media usage
## Lets use groupby

df["COUNTRY"].value_counts()
# Out:
# United States            8797
# India                    3806
# Germany                  2450
# United Kingdom           2414
# Canada                   1446
#                          ...
# Seychelles                  1
# Saint Kitts and Nevis       1
# Lesotho                     1
# Mali                        1
# Gabon                       1
# Name: COUNTRY, Length: 172, dtype: int64

# %%
country_grp=df.groupby(["Country"])

df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df["JobSeek"].value_counts()
# Out:
# I’m not actively looking, but I am open to new opportunities    47260
# I am not interested in new job opportunities                    21080
# I am actively looking for a job                                 12215
# Name: JobSeek, dtype: int64

# %%
country_grp.get_group("United States")

# %%
grped=df.groupby(["Country","JobSeek"])

# %%
grped.first()
# Out:
#                                                                 Respondent  \
# Country     JobSeek
# Afghanistan I am actively looking for a job                           6417
#             I am not interested in new job opportunities               722
#             I’m not actively looking, but I am open to new ...        7085
# Albania     I am actively looking for a job                           6206
#             I am not interested in new job opportunities              9229
# ...                                                                    ...
# Yemen       I’m not actively looking, but I am open to new ...        1129
# Zambia      I am actively looking for a job                          14806
#             I’m not actively looking, but I am open to new ...       11557
# Zimbabwe    I am actively looking for a job                            251
#             I’m not actively looking, but I am open to new ...        1886
#
# ...
