# %% [markdown]
# # Problem : Create a function that takes two numbers as argument and returns the greater of the two.

# %%
## a = 5
## b = 6

def compare(a,b):
    if a>b:
        number = a
    else:
        number = b
    
    return number

compare(5,6)
# Out:
# 6

# %%
div3(3,9)
# Out:
# 3 is divisible by 3
# 9 is divisible by 3

# %%
def div3(a, b):
    if(a%3==0):
        print(a, "is divisible by 3")
    else:
        print(a, "is not divisible by 3")
    if(b%3==0):
        print(b, "is divisible by 3")
    else:
        print(b, "is not divisible by 3")

# %%
def compare(a,b):
    if(a>b):
        greater = a
    else:
        greater = b
    
    return greater

# %%
#PI = 3.14
def peri(a):
    perimeter = (2*3.14*a)
    return perimeter

# %%
result=peri(6)

# %%
print(result)
# Out:
# 37.68

# %%
compare(109,500)
# Out:
# 500

# %%
## Area

def circle_area(radius):
    area = 2*3.14*radius
    return perimeter

# %%
circle_area(3)
# Out:
# 9.42

# %%
def area(r): 
  pie=22.7 
  area=pie*(r*r) 
  return area

area(1/3.14*3.14)
# Out:
# 22.7

# %%
def Area(r):
    area = 3.14*r*r
    return area

# %%
Area(11)
# Out:
# 379.94

# %%
def compare (a,b):
  if(a>b):
    greater = a
  else: 
    greater = b
  return greater
#compare (50,15)

# %%
compare (50,15)
# Out:
# 50

# %%
def compare(a,b):
    if(a>b):
        greater = a
    else:
        greater = b
    return greater

compare(12,50)
# Out:
# 50

# %%
def max(a,b,c):
  if a>b and a>c:
    return a
  elif b>c:
    return b
  else:
    return c

# %%
max(12,5,2)
# Out:
# 12

# %%
## this function takes teo numbers as input and prints the even numbers from that range
def even(a,b):
    for x in range(a,b): ## comment
        if(x%2==0):
            print(x)

# %%
even(12324,12344)
# Out:
# 12324
# 12326
# 12328
# 12330
# 12332
# 12334
# 12336
# 12338
# 12340
# 12342

# %%
def geteven(x,y):
    if( x % 2== 0):
        print("The value ", x, "is even")
    elif(y%2==0):
        print("the value", y, "is even")
    else:
        print("both  values are odd" )

# %%
def swap(a,b):
    c = a
    a = b
    b = c
    return(a,b)

# %%
def geteven(x,y):
    if( x % 2== 0):
        print("The value ", x, "is even")
    elif(y%2==0):
        print("the value", y, "is even")
    else:
        print("both  values are odd" )

# %%
geteven(5,11)
# Out:
# both  values are odd

# %%
## a = 4
## b = 5

a = 5
b = 4



Red ball     Blue ball     Third(temp ball)
red ribbons  blue ribbons   -----
----         blue ribbons   red ribbons
blue ribbons  -----         red ribbons
blue ribbons  red ribbons   -----



a   b    c

4   5    -
-   5    4
5   -    4
5   4    -

# %%
def swap(a,b):
    c=a
    a=b
    b=c
    return(a,b)

# %%
swap(4,5)
# Out:
# (5, 4)

# %%
## WAF to accept lower case letters and return upper case letters?
## biology

## BIOLOGY

# %%
## WAF which takes a range (i.e. two arguments) and prints all the numbers divisible by 11 
## in between those two numbers?

# %%
def up(a):
    return(a.upper())

# %%
up("jdksfjds")
# Out:
# 'JDKSFJDS'

# %%
lower=int(input("Enter lower range limit:"))
upper=int(input("Enter upper range limit:"))
n=int(input("Enter the number to be divided by:"))
for i in range(lower,upper+1):
    if(i%n==0):
        print(i)
# Out:
# Enter lower range limit:400
# Enter upper range limit:500
# Enter the number to be divided by:11
# 407
# 418
# 429
# 440
# 451
# 462
# 473
# 484
# 495

# %%
def divi(a,b):
 for i in range(a,b):
   if (i%11==0):
     print(i, "is divisible by 11")

divi(5,100)
# Out:
# 11 is divisible by 11
# 22 is divisible by 11
# 33 is divisible by 11
# 44 is divisible by 11
# 55 is divisible by 11
# 66 is divisible by 11
# 77 is divisible by 11
# 88 is divisible by 11
# 99 is divisible by 11

# %%
def comp(a,b,c):
    if a>b and a>c:
        return a
    elif b>a and b>c:
        return b
    else:
        return c

# %%
comp(3,-4,91)
# Out:
# 91

# %%
comp(90,-40,90)
# Out:
# 90

# %%
a = 5
b = 7


a = 7
b = 5

# %%
def swap(a,b):
    print("a =",a)
    print("b =",b)
    print("-------------")
    b,a = a,b
    print("a =",a)
    print("b =",b)

# %%
swap(12,14)
# Out:
# a = 12
# b = 14
# -------------
# a = 14
# b = 12
