# %% [markdown]
# <h2 style="color:Brown"> Variables</h2>

# %%
name="mike"  ## Assigning a value to a variable
print(name)
# Out:
# mike

# %%
name=input("Enter your name : ") ## How to take input from the user?
print("Welcome ", name) ## Printing your custom string and the value inside the variable together
print("Welcome", name)

# %%
print("Jyoti") #python3

# %%
name=input("Whats this?")
# Out:
# Whats this?now its working

# %%
age=29
print(age)
# Out:
# 29

# %%
type(name)
# Out:
# str

# %%
name = int(input("Enter your dob : "))  # Type casting
# Out:
# Enter your dob : 34

# %%
type(name)
# Out:
# int

# %% [markdown]
# <h2 style="color:Brown"> Constants</h2>

# %%
x=10
print(x)

# %%
## VAriable names not acceptable in python
@the=9
# Out:
#   File "<ipython-input-13-3bb4dcbb9d03>", line 2
#     @the=9
#         ^
# SyntaxError: invalid syntax

# %%
_the=9

# %%
_the
# Out:
# 9

# %%
## finding the length of the string
HAGT="Machine  Learning is  pointing     "

len(HAGT)
# Out:
# 35

# %% [markdown]
# <h2 style="color:Brown"> Data Types in Python

# %% [markdown]
# - Here in the below piece of code you can see that we have assigned each variable with a particular value and use the type method we can check the datatype of the variable

# %%
try_variable=3
print(try_variable)
print(type(try_variable))
# Out:
# 3
# <class 'int'>

# %%
integer_num = 1
floating_num = 1.3
string = "Mike"  ## Object 
boolean = True  ## 1 ## False 0

print (type(integer_num))
print (type(floating_num))
print (type(string))
print (type(boolean))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
classes_in_python = ["int", "float", "str", "bool"]   ## list datatype
type(classes_in_python)
# Out:
# list

# %%
fl=2.18
print(type(fl))
print(str(fl))

fl_str=str(fl)
print(type(fl_str))

# %%
a_str=str(a)
b_str=str(b)
print(type(a_str))
print(type(b_str))
a_str+b_str

# %%
first_name="Jyoti"
last_name="Kataria"

print(first_name+last_name)  ##

print(first_name+" "+last_name) 
print(first_name,last_name) ###
# Out:
# JyotiKataria
# Jyoti Kataria
# Jyoti Kataria

# %%
Name = "Jyoti"
Name1 = "Malika"
print(len(Name)>len(Name1))
# Out:
# False

# %%
code="three"
#print(Code)

print("where is your home")
print("Where is your home?")
# Out:
# where is your home
# Where is your home?

# %%
print(5/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-fad870a50e27> in <module>()
# ----> 1 print(5/0)
#
# ZeroDivisionError: division by zero

# %%
classes_in_python

# %% [markdown]
# - Type Casting in Python

# %%
a = 1
#print ( bool(a))
#print (float(a))
#print ( str(a))
#print(type(a))

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

print(type(a))
print(str(a))
print(bool(a))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-55ca2bf0fde4> in <module>
#       2 InteractiveShell.ast_node_interactivity = "all"
#       3
# ----> 4 print(type(a))
#       5 print(str(a))
#       6 print(bool(a))
#
# NameError: name 'a' is not defined

# %%
a
# Out:
# 1

# %%
a=2
bool(a)
b=""
bool(b)

# %%
Boolean : True or False
    1 or 0

# %%
type(a)

# %% [markdown]
# <h2 style="color:Brown"> Arithmetic Operations

# %%
age=int(input("Enter your age "))
print(type(age))
# Out:
# Enter your age 12
# <class 'int'>

# %%
a = 6
b = 7

addition=a+b
subtraction=a-b

print("Addition  = ", a + b)  
print("Subraction = ", a - b) 
print("Multiplication = ", a * b) 
print("Division = ", a / b)

# %%
print(int(input ("enter the first number")))

# %%
num1_int=int(num1)

# %%
print(type(num1))

# %%
a - b

# %%
print("Addition  =  a + b")

# %%
#Floor Division
a=146

b=13

print("Floor Division = ", a // b)
# Out:
# Floor Division =  11

# %%
a

# %%
b

# %%
print("Floor Division = ", a // b)

# %%
x = 3
y = 2

x//y

# %%
#Remainder
print("Modulus or remainder",a % b)

# %%
print("what is the result of 13456 % 1234")
# Out:
# what is the result of 13456 % 1234

# %%
13456 % 1234
# Out:
# 1116

# %%
print("345 to the power 5")

# %%
345**5
# Out:
# 4887597965625

# %%
print("24 to the power 2")

# %%
24**2
# Out:
# 576

# %%
x = int(input("Enter a number: "))
y = int(input("Enter a number: "))


type(x)
type(y)
# Out:
# Enter a number: 34
# Enter a number: 32
# int

# %%
#Exponential
print("Exponential = ", a ** b)

# %% [markdown]
# - Expression executes following the operator precedence rule
# - https://docs.python.org/3.7/reference/expressions.html?#operator-precedence

# %%
print((4 * 5) - 9 + 6 / 7) ## BODMAS  20-9+0.8
# Out:
# 11.857142857142858

# %% [markdown]
# <h2 style="color:Brown"> String Operations

# %%
#Whenever we are assigning a char or string we use '' which represents a character
c = 'z'
d = 'Mike'
#You can also use " " double quotes instead of single quotes for strings
e = "John"

# %%
print("What is your \t \t name \n")
print('What is your \t \t name \n')
#print("Where are you from \n")
# Out:
# What is your 	 	 name
#
# What is your 	 	 name

# %%
print("mdndskjhfkje")
print("gashdva")
print("sdhsfg")


print("-------------------------")
print("dhgfdgsfsj\ndjfhdsjfhdjhf\n")
# Out:
# mdndskjhfkje
# gashdva
# sdhsfg
# -------------------------
# dhgfdgsfsj
# djfhdsjfhdjhf

# %%
\n new line
\t tab

# %%
print('What is your \t \t name \n')

print("Hi ","\\t","How are you")
print(r"\t", "Hello")
# Out:
# What is your 	 	 name
#
# Hi  \t How are you
# \t Hello

# %% [markdown]
# #### Indexing In Strings <br>
# - Forward indexing starts with 0
# - Reverse indexing start with last character as -1 in a python string
# - Strings are immutable which means they cannot be changed once created.
# - Strings can be modified by slicing a part of it and concatenating with another

# %%
Five_numbers = [1, 2, 3, 4, 5] 

                0  1  2   3  
type(Five_numbers)
# Out:
# list

# %%
Five_numbers[-1]
# Out:
# 5

# %%
#Five_numbers[0]
Five_numbers[:4]
# Out:
# [1, 2, 3, 4]

# %%
# len() function
string = "ABCDE  FGH"
len(string)
# Out:
# 10

# %%
#Accessing first character
string[0]
# Out:
# 'A'

# %%
#Accessing last character using negative indexing
string[-1]
# Out:
# 'H'

# %%
# Trying to change the character at index 2 ## We cannot change a string or mutate it
string[2] = 't'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-790780a9a8cc> in <module>
#       1 # Trying to change the character at index 2 ## We cannot change a string or mutate it
# ----> 2 string[2] = 't'
#
# TypeError: 'str' object does not support item assignment

# %%
string[2]

# %%
string

# %%
# Changing the entire string
string = 'ghijkl'
print (string)

# %%
#string concatenation

first_name = "Monty"
last_name = 'Python'

# %%
print("The name is: " + first_name+" "+last_name) ## You can use comma also 
print("The name is:",first_name,last_name)
# Out:
# The name is: Monty Python
# The name is: Monty Python

# %%
# type casting using str() function 
age=30
type(age)
# Out:
# int

# %%
name=input("Enter your name:")
age=int(input("Enter your age"))
print("My name is", name, "my age is",age)
# Out:
# Enter your name:Kiara
# Enter your age43
# My name is Kiara my age is 43

# %%
print("I am "+ str(age) + " years old")
#print("I am "+ age + " years old")
#print("I am" , age, "years old")
# Out:
# I am 43 years old

# %%
n = input("Your name: ")
m = input("Mother's name: ")
f = input("Father's name: ")

# %%
print("I am "+ age + " years old")

# %%
print('My name is '+n+ ".\nMy mother's name is "+m+ ".\nMy father's name is "+f+ ".\nWe live in Mumbai. \nWe have lived here for 10 years." )

# %% [markdown]
# #### Slicing In Strings
# - string[start:end:step]

# %%
list1 = ["I","am","learning","Python","Programming"]

#[len(word) for word in list1]

# %%
#float, integer, str, bool = one value
#data structure which can store more than one value?


list1 = ["I","am","learning","Python","Programming"]

print(list1)
print(type(list1))



list1[3]
# Out:
# ['I', 'am', 'learning', 'Python', 'Programming']
# <class 'list'>
# 'Python'

# %%
#slicing by specifying start and end index
statement = "Python programming is fun"  ## hon programming is
            
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

#sliced_statement = statement[11:25]
statement[3:-4]
# Out:
# 'hon programming is'

# %%
#len(statement)
statement[7:16]

statement[7:-4]
statement[16]
# Out:
# 'programmi'
# 'programming is'
# 'n'

# %%
statement[7]

# %%
statement[:5]
# Out:
# 'Pytho'

# %%
statement[4:]
# Out:
# 'on programming is fun'

# %%
statement

# %%
statement[4]

# %%
batch = "5 girls 3 boys in a class"


girls = batch[ :8]
print(girls)

print(batch[ 8: ])

# %%
# Slicing by specifing range

nums = '123456789'
even_nums = nums[1::2]
odd_nums=nums[0::2]

#slicing[start:end:skip_by]

print("The even numbers are: ",even_nums)
print("The odd numbers are:",odd_nums)
# Out:
# The even numbers are:  2468
# The odd numbers are: 13579

# %%
nums[1::3]

# %%
# printing odd_nums
odd_nums = nums[0::2]
print(odd_nums)

# %%
# Membership 
String = "John! Did you attend the conference on advanced machine learning"
print( 'John' in String)
print ( 'David' not in String)

# %%
"Conference" in String  ## Python is case sensitive

# %%
!=

==

# %%
4**2
# Out:
# 16

# %%
# Repeatition

String = "abcd"
print(String*4)
# Out:
# abcdabcdabcdabcd

# %% [markdown]
# #### String methods
# - upper()
# - lower()
# - strip()
# - count(substring,begin,end)
# - https://docs.python.org/3.7/library/stdtypes.html#string-methods

# %%
# upper() 
small = "i am upper cased"
print(small.upper())
# Out:
# I AM UPPER CASED

# %%
string1 = "ATDWRFjhhdgfhjeorur"

print(string1.lower())
# Out:
# atdwrfjhhdgfhjeorur

# %%
print(string1.upper())
print(string1.lower())

# %%
# lower() 
large = "I AM LOWER CASED"
print(large.lower())

# %%
len(some_sentence)
print("\n")
some_sentence = "There is a space at the end"
len(some_sentence)
# Out:
# 27
# 27

# %%
# rstrip () function
some_sentence = "There is a space at the end    "
print(some_sentence)
print(some_sentence.rstrip())
# Out:
# There is a space at the end
# There is a space at the end

# %%
some="##@$SSGXHHGTYTHTH********"
some.rstrip("*")
# Out:
# '##@$SSGXHHGTYTHTH'

# %%
string2 = "tyruehfdskjfhdsjkfhjds%%%%%%%%%%"

# %%
tyruehfdskjfhdsjkfhjds

# %%
increment = '4%'
print(increment.rstrip('%'))

# %%
### Chip off the unncessary characters from the following string


string_to_clean = "!@#@#My name is Priya #$@!"

#cleaned_string = "My name is Priya"

# %%
print(string_to_clean.rstrip("#$@!").lstrip("!@#@#"))
# Out:
# My name is Priya

# %%
## string1 = " hsdghsjshfks  hdhs"

# %%
# lstrip() function
start = "   There is space at the start"
print(start)
print(start.lstrip())

# %%
# strip() function 
spaces = "$$$$Jyoti$$$$$"
###Jyoti
print(spaces)
print(spaces.strip())
# Out:
#    Trim whitespaces
# Trim whitespaces

# %%
clean_this_string = "@@@@@@@machine_learning_module%%%%%%"

# %%
print(clean_this_string.strip('@').strip('%'))
# Out:
# machine_learning_module

# %%
cleaned_string = "machine_learning_module"

# %%
cleaned_string

# %%
clean_this_string.rstrip("%").lstrip("@")

# %%
clean_this_string.strip("%""@") ### Use two characters to be replaced at the same time
# Out:
# 'machine_learning_module'

# %%
num_with_chars = '******444#######'
print(num_with_chars.rstrip('#').lstrip('*'))

# %%
string.count("i")

# %%
string

# %%
#count() Method
string = "This is a sample sentence"
print(string.count('i'))
print(string.count('i',4))
# Out:
# 2
# 1

# %%
string4="How about we do the tasks by devoting good time at home and not rushing through it"
string4.count('t')
# Out:
# 9

# %%
My_age = "I am {} years old".format(age)

# %%
name="Jyoti"
class="second year bsc"
city="Bangalore"
print("my name is  ", name)
# Out:
# my name is   Jyoti

# %%
A="Miloni"
B="MSc"
C="Mumbai"
D="Saint Xaviers College"
print("{} {} using {} {}".format (A,B,C,D))
# Out:
# Miloni MSc using Mumbai Saint Xaviers College

# %%
n = input("Enter your name: ")
a = input("Enter your Age: ")
c = input("Enter your city: ")
print("My name is {}. \nI am {} years old. \nI live in {}".format(n, a, c))
# Out:
# Enter your name: jk
# Enter your Age: 27
# Enter your city: Bangalore
# My name is jk.
# I am 27 years old.
# I live in Bangalore
