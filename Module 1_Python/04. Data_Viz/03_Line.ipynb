# %% [markdown]
# ## Visualisation in Python - Matplotlib

# %% [markdown]
# ### Line Chart: RBC count over the 12 months

# %% [markdown]
# -  Can be used to present the trend with time variable on the x-axis
# -  In some cases, can be used as an alternative to scatterplot to understand the relationship between 2 variables

# %%
# importing the required libraries
import numpy as np
import matplotlib.pyplot as plt

# Sales data across months
months = np.array(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
sales = np.array([241268.56, 184837.36, 263100.77, 242771.86, 288401.05, 401814.06, 258705.68, 456619.94, 481157.24, 422766.63, 555279.03, 503143.69])

# %%
# plotting a line chart

plt.plot(months, sales)
# adding title to the chart
plt.title("Sales across months of 2015")

# labeling the axes
plt.xlabel("Months")
plt.ylabel("Sales")

# rotating the tick values of x-axis

plt.xticks(rotation=90)
#plt.yticks(rotation = 90)  #could do for xticks as well

# displaying the created plot
plt.show()

# %%
np.random.randint(1,100,50)
# Out:
# array([ 4, 96,  5, 14, 18, 63, 92, 74, 69,  2, 11, 30, 40, 92, 74, 83, 41,
#        57, 38, 50, 47,  9, 26, 62, 31, 84, 14,  6, 40, 42, 32, 71, 43, 74,
#        48, 76, 15, 98,  4, 55, 87, 53, 13, 66, 26, 48, 22, 92, 17, 12])

# %%
np.random.randint(1,100,50)
# Out:
# array([74, 28, 54, 28, 61, 65, 31, 83, 91, 29, 40, 98, 44,  3, 53, 40, 94,
#        37, 55, 27, 25, 75, 93, 55, 42, 76, 84,  4, 41, 25, 74, 18, 58, 65,
#        88, 17, 15, 27, 68, 13, 51,  4,  9, 63, 81, 90, 52, 93, 19, 35])

# %%
y = np.random.randint(1,100, 50)
plt.plot(y, 'ro') # ‘ro’ represents color (r) and marker (o)
plt.show()

##The randint() method returns an integer number selected element from the specified range.
y
# Out:
# array([58, 65, 97, 54, 97,  2, 35, 88, 94, 88, 44, 26, 15,  5, 89, 21, 61,
#        52, 37, 33, 84, 21, 55, 90, 34, 48, 37, 18, 83, 43, 82, 94, 47, 19,
#         6, 17, 41, 11, 93, 72, 93, 82, 51, 74, 77, 80, 44, 57, 94, 92])

# %%
months1=np.array(['Jan','Feb','March','April'])
sales1=np.array([51268,63232,73232,82332])
months2=np.array(['Jan','Feb','March','April'])
sales2=np.array([91244,65223,22444,12552])
plt.plot(months1,sales1,'b+',months2,sales2,'r+')
plt.show()

# %%
plt.plot(y, 'red', marker = 'o')
plt.show()

# %%
months = np.array(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
sales = np.array([241268.56, 184837.36, 263100.77, 242771.86, 288401.05, 401814.06, 258705.68, 456619.94, 481157.24, 422766.63, 555279.03, 503143.69])
sales2 = np.array([261268.56, 194837.36, 283100.77, 292771.86, 228401.05, 421814.06, 278705.68, 486619.94, 451157.24, 442766.63, 575279.03, 593143.69])
plt.plot(months, sales)
plt.plot(months,sales2, 'bo' )
plt.title("Sales acorss month of 2015")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.xticks(rotation=90)
plt.show()

# %%
x=[1,2,3,4]
y=[5,4,5,6]
plt.plot(x,y)
plt.show()

# %%
plt.plot(x, y, 'bo') 
plt.show()

# %%
plt.plot(x, y, 'b', marker = 'x')
plt.show()


#The syntax for plotting a line graph is plt.plot(x_component, y-component, 'graph_features'). You have to specify the marker as a separate attribute to plot a line graph.

# %%
months = np.array(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
sales = np.array([241268.56, 184837.36, 263100.77, 242771.86, 288401.05, 401814.06, 258705.68, 456619.94, 481157.24, 422766.63, 555279.03, 503143.69])
sales2 = np.array([261268.56, 194837.36, 283100.77, 292771.86, 228401.05, 421814.06, 278705.68, 486619.94, 451157.24, 442766.63, 575279.03, 593143.69])
plt.plot(months,sales,'red',months,sales2,'green')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15, 6))


plt.plot(months,sales,marker='>')
plt.plot(months,sales2,color='green',marker='o')
