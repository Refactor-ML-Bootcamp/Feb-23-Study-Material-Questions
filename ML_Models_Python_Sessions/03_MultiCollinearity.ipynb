# %% [markdown]
# ## Multicollinearity In Linear Regression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd


features a-z


y = constant + coeff1 X a + coeff2 X b + ...... + ... n

# %%
import statsmodels.api as sm

df_adv = pd.read_csv('/content/drive/MyDrive/Refactor_Notes/ML_Models_Python_Sessions/Data_files/Advertising.csv',index_col=0)

df_adv.head(5)
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
X = df_adv[['TV', 'radio','newspaper']]
y = df_adv['sales']
df_adv.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
## Ordinary Least Squares regression (OLS) is a common technique for 
## estimating coefficients of linear regression equations which describe the 
## relationship between one or more independent quantitative variables 
## and a dependent variable (simple or multiple linear regression).

# %%
X = sm.add_constant(X)
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
X
# Out:
#      const     TV  radio  newspaper
# 1      1.0  230.1   37.8       69.2
# 2      1.0   44.5   39.3       45.1
# 3      1.0   17.2   45.9       69.3
# 4      1.0  151.5   41.3       58.5
# 5      1.0  180.8   10.8       58.4
# ..     ...    ...    ...        ...
# 196    1.0   38.2    3.7       13.8
# 197    1.0   94.2    4.9        8.1
# 198    1.0  177.0    9.3        6.4
# 199    1.0  283.6   42.0       66.2
# 200    1.0  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
## fit a OLS model with intercept on TV and Radio and newspaper

model= sm.OLS(y, X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Sat, 24 Dec 2022   Prob (F-statistic):           1.58e-96
# Time:                        09:28:54   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
X.head(2)
# Out:
#    const     TV  radio  newspaper
# 1    1.0  230.1   37.8       69.2
# 2    1.0   44.5   39.3       45.1

# %%
import matplotlib.pyplot as plt
X.iloc[:,1:].corr()
# Out:
#                  TV     radio  newspaper
# TV         1.000000  0.054809   0.056648
# radio      0.054809  1.000000   0.354104
# newspaper  0.056648  0.354104   1.000000

# %%
df_salary = pd.read_csv('/content/drive/MyDrive/Refactor_Notes/ML_Models_Python_Sessions/Data_files//Salary_Data.csv')
df_salary.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
X = df_salary[['YearsExperience', 'Age']]
y = df_salary['Salary']

# %%
## fit a OLS model 
X = sm.add_constant(X)
model= sm.OLS(y, X).fit()
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     323.9
# Date:                Sat, 24 Dec 2022   Prob (F-statistic):           1.35e-19
# Time:                        10:05:54   Log-Likelihood:                -300.35
# No. Observations:                  30   AIC:                             606.7
# Df Residuals:                      27   BIC:                             610.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
X.iloc[:,1:].corr()
# Out:
#                  YearsExperience       Age
# YearsExperience         1.000000  0.987258
# Age                     0.987258  1.000000

# %%
### How to solve this multicollinearity issue?

## Which feature to drop?
## Don't care about multi-collinearity!!!
